# %%
import pandas as pd 
import numpy as np
from pathlib import Path

# %%
col_nums_value=[]
for x in range(5,269)
    col_nums_value.append(x)

# %%
# Read in ZHVI
file_path = Path("resources/zillow_home_value_index.csv")
home_value_index = pd.read_csv(file_path, parse_dates=col_nums_value, infer_datetime_format=True)
home_value_index.head(10)
# Out:
#    RegionID  SizeRank                          RegionName RegionType  \
# 0    102001         0                       United States    Country
# 1    394913         1                        New York, NY        Msa
# 2    753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3    394463         3                         Chicago, IL        Msa
# 4    394514         4               Dallas-Fort Worth, TX        Msa
# 5    394974         5                    Philadelphia, PA        Msa
# 6    394692         6                         Houston, TX        Msa
# 7    395209         7                      Washington, DC        Msa
# 8    394856         8           Miami-Fort Lauderdale, FL        Msa
# 9    394347         9                         Atlanta, GA        Msa
#
#   StateName 1/31/2000 2/29/2000 3/31/2000 4/30/2000 5/31/2000  ... 3/31/2021  \
# 0       NaN    127090    127434    127795    128532    129274  ...    278389
# ...

# %%
home_value_index.dtypes
# Out:
# RegionID       int64
# SizeRank       int64
# RegionName    object
# RegionType    object
# StateName     object
#                ...
# 8/31/2021     object
# 9/30/2021     object
# 10/31/2021    object
# 11/30/2021    object
# 12/31/2021    object
# Length: 269, dtype: object

# %%
# Drop RegionType and StateName
home_value_index.drop(columns=['RegionType', 'StateName'], inplace=True)
home_value_index.head()
# Out:
#    RegionID  SizeRank                          RegionName 1/31/2000 2/29/2000  \
# 0    102001         0                       United States    127090    127434
# 1    394913         1                        New York, NY    223496    224831
# 2    753899         2  Los Angeles-Long Beach-Anaheim, CA    231337    232142
# 3    394463         3                         Chicago, IL    168878    169276
# 4    394514         4               Dallas-Fort Worth, TX    130599    130703
#
#   3/31/2000 4/30/2000 5/31/2000 6/30/2000 7/31/2000  ... 3/31/2021 4/30/2021  \
# 0    127795    128532    129274    130015    130770  ...    278389    282245
# 1    226033    228398    230600    232945    235408  ...    523812    528535
# 2    233376    235722    238237    240612    243044  ...    757038    768091
# 3    169792    170824    171917    173001    174201  ...    260755    263775
# 4    130790    131002    131225    131411    131610  ...    285247    290780
#
# ...

# %%
df_2 = pd.melt(home_value_index, id_vars = ['RegionName', 'RegionID', 'SizeRank'])
               
df_2
# Out:
#                                 RegionName  RegionID  SizeRank    variable  \
# 0                            United States    102001         0   1/31/2000
# 1                             New York, NY    394913         1   1/31/2000
# 2       Los Angeles-Long Beach-Anaheim, CA    753899         2   1/31/2000
# 3                              Chicago, IL    394463         3   1/31/2000
# 4                    Dallas-Fort Worth, TX    394514         4   1/31/2000
# ...                                    ...       ...       ...         ...
# 239707                          Lamesa, TX    394767       929  12/31/2021
# 239708                           Craig, CO    753874       930  12/31/2021
# 239709                           Pecos, TX    394968       931  12/31/2021
# 239710                          Vernon, TX    395188       932  12/31/2021
# 239711                       Ketchikan, AK    394743       933  12/31/2021
#
#          value
# 0       127090
# 1       223496
# 2       231337
# ...

# %%
df_2.rename(columns={'variable' : 'Date'})
# Out:
#                                 RegionName  RegionID  SizeRank        Date  \
# 0                            United States    102001         0   1/31/2000
# 1                             New York, NY    394913         1   1/31/2000
# 2       Los Angeles-Long Beach-Anaheim, CA    753899         2   1/31/2000
# 3                              Chicago, IL    394463         3   1/31/2000
# 4                    Dallas-Fort Worth, TX    394514         4   1/31/2000
# ...                                    ...       ...       ...         ...
# 239707                          Lamesa, TX    394767       929  12/31/2021
# 239708                           Craig, CO    753874       930  12/31/2021
# 239709                           Pecos, TX    394968       931  12/31/2021
# 239710                          Vernon, TX    395188       932  12/31/2021
# 239711                       Ketchikan, AK    394743       933  12/31/2021
#
#          value
# 0       127090
# 1       223496
# 2       231337
# ...

# %%
df_2.to_csv("home_value_index_new_data.csv")

# %%
import numpy as np
col_nums=[]
for x in range(3,99):
    col_nums.append(x)

# %%
# Read in ZORI 


file_path = Path("resources/zillow_observed_rent_index.csv")
rental_index = pd.read_csv(file_path, parse_dates=col_nums, infer_datetime_format=True)
rental_index.head(10)
# Out:
#    RegionID                          RegionName  SizeRank 2014-01 2014-02  \
# 0    102001                       United States         0    1318    1324
# 1    394913                        New York, NY         1    4684    4705
# 2    753899  Los Angeles-Long Beach-Anaheim, CA         2    1750    1761
# 3    394463                         Chicago, IL         3    1405    1409
# 4    394514               Dallas-Fort Worth, TX         4    1128    1131
# 5    394974                    Philadelphia, PA         5    1331    1333
# 6    394692                         Houston, TX         6    1161    1168
# 7    395209                      Washington, DC         7    1772    1774
# 8    394856           Miami-Fort Lauderdale, FL         8    1563    1570
# 9    394347                         Atlanta, GA         9    1078    1082
#
#   2014-03 2014-04 2014-05 2014-06 2014-07  ... 2021-03 2021-04 2021-05  \
# 0    1329    1334    1340    1345    1351  ...    1723    1741    1761
# ...

# %%
datatypes = rental_index.dtypes
datatypes
# Out:
# RegionID       int64
# RegionName    object
# SizeRank       int64
# 2014-01       object
# 2014-02       object
#                ...
# 2021-08       object
# 2021-09       object
# 2021-10       object
# 2021-11       object
# 2021-12       object
# Length: 99, dtype: object

# %%
df_1 = pd.melt(rental_index, id_vars = ['RegionName', 'RegionID', 'SizeRank'])
               
df_1
# Out:
#                               RegionName  RegionID  SizeRank variable value
# 0                          United States    102001         0  2014-01  1318
# 1                           New York, NY    394913         1  2014-01  4684
# 2     Los Angeles-Long Beach-Anaheim, CA    753899         2  2014-01  1750
# 3                            Chicago, IL    394463         3  2014-01  1405
# 4                  Dallas-Fort Worth, TX    394514         4  2014-01  1128
# ...                                  ...       ...       ...      ...   ...
# 9787                       Melbourne, FL    394957        97  2021-12  1776
# 9788                         Spokane, WA    395113        99  2021-12  1565
# 9789                           Provo, UT    395006       100  2021-12  1643
# 9790                         Killeen, TX    394746       128  2021-12  1316
# 9791                 College Station, TX    394483       192  2021-12  1556
#
# [9792 rows x 5 columns]

# %%
df_1.to_csv("rental_index_new_data.csv")

# %%
df_1.rename(columns={'variable' : 'Date'})
# Out:
#                               RegionName  RegionID  SizeRank     Date value
# 0                          United States    102001         0  2014-01  1318
# 1                           New York, NY    394913         1  2014-01  4684
# 2     Los Angeles-Long Beach-Anaheim, CA    753899         2  2014-01  1750
# 3                            Chicago, IL    394463         3  2014-01  1405
# 4                  Dallas-Fort Worth, TX    394514         4  2014-01  1128
# ...                                  ...       ...       ...      ...   ...
# 9787                       Melbourne, FL    394957        97  2021-12  1776
# 9788                         Spokane, WA    395113        99  2021-12  1565
# 9789                           Provo, UT    395006       100  2021-12  1643
# 9790                         Killeen, TX    394746       128  2021-12  1316
# 9791                 College Station, TX    394483       192  2021-12  1556
#
# [9792 rows x 5 columns]
